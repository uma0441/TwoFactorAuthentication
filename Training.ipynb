# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv2D, Input, MaxPooling2D, Lambda, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import l2
import os

import glob
import numpy as np
from PIL import Image

class Siamese_Loader:
    """For loading batches and testing tasks to a siamese net"""
    def __init__(self, path, data_subsets=["train", "val"]):
        print("hh")
        # gets all file paths (separate for each person)
        self.file_set = [file for file in (glob.glob(r'C:\Users\S545241\Desktop\ecg_img\ecg-id-database-filter\Person_{:02d}/*.png'.format(num)) for num in range(1, 89))]
        print(self.file_set)
        # defining train and val set
        self.val_set = [1, 6, 13, 15, 21, 25, 29, 38, 41, 44, 52, 62, 68, 74, 80]
        #self.val_set = [1]
        self.train_set = list(range(1, 85))
        for ele in sorted(self.val_set, reverse=True):  
            del self.train_set[ele-1]

    def get_batch(self, batch_size, s="train"):
        """Create batch of n pairs, half same class, half different class"""
      
        if s=='train':
          ids = self.train_set
          #print(ids)
        else:
          ids = self.val_set

        w, h = 144, 224

        #initialize 2 empty arrays for the input image batch
        pairs = [np.zeros((batch_size, w, h, 1)) for i in range(2)]
        #initialize vector for the targets, and make one half of it '1's, so 2nd half of batch has same class
        targets = np.zeros((batch_size,))
        targets[batch_size//2:] = 1

        for i in range(batch_size):
            # select random person
            idx_1, idx_2 = np.random.choice(ids, size=2).tolist()
            #print(idx_1)
            #print(idx_2)
            #print(self.file_set[idx_1-2])
            # select random ecg sample of the person
            try:
                pair_x, pair_y = np.random.choice(self.file_set[idx_1-2],size=2, replace = False).tolist()
            except ValueError:
                pair_x, pair_y = np.random.choice(self.file_set[idx_1-2],size=2, replace=True).tolist()

            #(pair_x,pair_y).tolist()
            #print(pair_x)
            #print("y: ", pair_y)
            
            # load and format the image
            
            img = Image.open(pair_x)
            img = img.resize((h, w))
            #img.show()
            pairs[0][i,:,:,:] = np.array(img)[:,:,0:1] / 255

            #pick images of same class for 1st half, different for 2nd
            if i < batch_size // 2:
                pair_y = np.random.choice(self.file_set[idx_2-2], 1)[0]
                #print(pair_y)

            img = Image.open(pair_y)
            img = img.resize((h, w))
            #img.show()
            pairs[1][i,:,:,:] = np.array(img)[:,:,0:1] / 255
            #print(pairs)
        return pairs, targets
    
    def generate(self, batch_size, s="train"):
        """a generator for batches, so model.fit_generator can be used. """
        while True:
            pairs, targets = self.get_batch(batch_size,s)
            yield (pairs, targets)    

    def make_oneshot_task(self, N, s="val"):
        """Create pairs of test image, support set for testing N way one-shot learning. """

        if s=='train':
          ids = self.train_set
        else:
          ids = self.val_set

        w, h = 144, 224

        # select random people
        try:
            idx = np.random.choice(ids, N, replace=False)
        except:
            idx = np.random.choice(ids, N, replace=True)
        true_idx = idx[0]      # test person
        false_idx = idx[1:]    # random people

        pairs = [np.zeros((N, w, h, 1)) for i in range(2)]

        # contains N-1 sample of random people, 1 sample of test person
        support_set = np.zeros((N, w, h, 1))
        # contains N sample of test person (1 person)
        test_image = np.zeros((N, w, h, 1))

        targets = np.zeros((N,))
        targets[0] = 1

        # gets file path of N+1 sample of test person
        pair_x = np.random.choice(self.file_set[true_idx-2], N+1).tolist()
        support_set[0] = np.array(Image.open(pair_x[0]).resize((h, w)))[:,:,0:1] / 255

        j = 0
        for i in pair_x[1:]:
          test_image[j] = np.array(Image.open(i).resize((h, w)))[:,:,0:1] / 255
          j += 1

        for i in range(1, N):
          pair_y = np.random.choice(self.file_set[false_idx[i-1]], 1, replace=False)[0]
          support_set[i] = np.array(Image.open(pair_y).resize((h, w)))[:,:,0:1] / 255
            
        # shuffle data
        index = list(range(N))
        np.random.shuffle(index)
        targets, test_image, support_set = targets[index], test_image[index], support_set[index]
        pairs = [test_image, support_set]

        return pairs, targets
    
    def test_oneshot(self, model, N, k, s="val", verbose=0):
        """Test average N way oneshot learning accuracy of a siamese neural net over k one-shot tasks"""
        n_correct = 0
        if verbose:
            print("\nEvaluating model on {} random {} way one-shot learning tasks ...".format(k,N))
        
        acc = []
        for i in range(k):
            inputs, targets = self.make_oneshot_task(N, s)
            probs = model.predict(inputs).reshape((N,))

            # check accuracy
            acc.append(np.argmax(probs)==np.argmax(targets))
            
        percent_correct = 100*sum(acc)/len(acc)

        if verbose:
            print("Got an average of {}% {} way one-shot learning accuracy".format(percent_correct,N))
        return percent_correct
    
    def train(self, model, epochs, verbosity):
        # train the model
        model.fit_generator(self.generate(batch_size))

def get_siamese_model(input_shape):
    """
    Model architecture based on the one provided in: http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
    """

    left_input = Input(input_shape)
    right_input = Input(input_shape)

    model = Sequential()
    model.add(Conv2D(32, (3,3), activation='relu', input_shape=input_shape, kernel_regularizer=l2(2e-4)))
    model.add(Conv2D(32, (3,3), activation='relu', kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    
    model.add(Conv2D(64, (3,3), activation='relu', kernel_regularizer=l2(2e-4)))
    model.add(Conv2D(64, (3,3), activation='relu', kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    
    model.add(Conv2D(128, (3,3), activation='relu', kernel_regularizer=l2(2e-4)))
    model.add(Conv2D(128, (3,3), activation='relu', kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    
    model.add(Conv2D(256, (3,3), activation='relu', kernel_regularizer=l2(2e-4)))
    model.add(Conv2D(256, (3,3), activation='relu', kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    
    model.add(Flatten())
    model.add(Dense(512, activation='sigmoid', kernel_regularizer=l2(1e-3)))
    
    encoded_l = model(left_input)
    encoded_r = model(right_input)
    #print(tensors[0])
    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    print(L1_layer)
    L1_distance = L1_layer([encoded_l, encoded_r])
    print(L1_distance)
    prediction = Dense(1,activation='sigmoid')(L1_distance)
    print(prediction)
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)
    print(siamese_net)
    return siamese_net

def train_model(model, loader, weights_path="model.h5"):
    evaluate_every = 20     # interval for evaluating on one-shot tasks
    loss_every = 5          # interval for printing loss (iterations)
    batch_size = 32
    n_iter = 1000
    N_way = 5               # how many people for testing one-shot tasks?
    n_val = 50              # how many one-shot tasks to validate on?
    best = 0

    train_loss, train_acc = [], []
     
    print("Starting training process!")
    print("-------------------------------------")
    for i in range(1, n_iter):
        (inputs, targets) = loader.get_batch(batch_size)
        loss = model.train_on_batch(inputs, targets)
        train_loss.append(loss)
        #print("loss: ",loss)

        if i%loss_every == 0:
          print("iteration {}, training loss: {:.2f},".format(i,loss))

        if i%evaluate_every == 0:
          val_acc = loader.test_oneshot(model, N_way, n_val, verbose=True)
          if val_acc >= best:
              print("Current best: {0}, previous best: {1}\n".format(val_acc, best))
              print("Saving weights to: {0} \n".format(weights_path))
              print(weights_path)
              model.save_weights(weights_path)
              #model.save()
              best = val_acc

if __name__ == '__main__':
    print("jj")
    model = get_siamese_model((144, 224, 1))
    optimizer = Adam(lr = 0.00006)
    model.compile(loss="binary_crossentropy", optimizer=optimizer)

    loader = Siamese_Loader(path="path-to-data")
    train_model(model, loader, weights_path = "model_ecg.h5")
# Out:
# jj
# <keras.layers.core.lambda_layer.Lambda object at 0x00000282AF54A350>
# KerasTensor(type_spec=TensorSpec(shape=(None, 512), dtype=tf.float32, name=None), name='lambda_4/Abs:0', description="created by layer 'lambda_4'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='dense_9/Sigmoid:0', description="created by layer 'dense_9'")
# <keras.engine.functional.Functional object at 0x00000282864518A0>
# hh
# [['C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_1.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_10.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_11.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_12.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_13.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_14.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_15.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_16.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_17.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_18.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_19.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_2.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_20.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_3.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_4.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_5.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_6.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_7.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_8.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_01\\rec_9.png'], ['C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_1.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_10.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_11.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_12.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_13.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_14.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_15.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_16.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_17.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_18.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_19.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_2.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_20.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_21.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_22.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_3.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_4.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_5.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_6.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_7.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_8.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_02\\rec_9.png'], ['C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_03\\rec_1.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_03\\rec_2.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_03\\rec_3.png', 'C:\\Users\\S545241\\Desktop\\ecg_img\\ecg-id-database-filter\\Person_03\\rec_4.png', 'C:\\Users\\S5 ...
# Starting training process!
# -------------------------------------
# iteration 5, training loss: 1.80,
# iteration 10, training loss: 1.76,
# iteration 15, training loss: 1.72,
# iteration 20, training loss: 1.68,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 64.0% 5 way one-shot learning accuracy
# Current best: 64.0, previous best: 0
#
# Saving weights to: model_ecg.h5
#
# model_ecg.h5
# iteration 25, training loss: 1.64,
# iteration 30, training loss: 1.61,
# iteration 35, training loss: 1.57,
# iteration 40, training loss: 1.54,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 86.0% 5 way one-shot learning accuracy
# Current best: 86.0, previous best: 64.0
#
# Saving weights to: model_ecg.h5
#
# model_ecg.h5
# iteration 45, training loss: 1.50,
# iteration 50, training loss: 1.47,
# iteration 55, training loss: 1.44,
# iteration 60, training loss: 1.40,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 78.0% 5 way one-shot learning accuracy
# iteration 65, training loss: 1.35,
# iteration 70, training loss: 1.26,
# iteration 75, training loss: 1.24,
# iteration 80, training loss: 1.22,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 74.0% 5 way one-shot learning accuracy
# iteration 85, training loss: 1.19,
# iteration 90, training loss: 1.08,
# iteration 95, training loss: 1.12,
# iteration 100, training loss: 0.97,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 52.0% 5 way one-shot learning accuracy
# iteration 105, training loss: 0.98,
# iteration 110, training loss: 1.02,
# iteration 115, training loss: 0.96,
# iteration 120, training loss: 0.98,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 48.0% 5 way one-shot learning accuracy
# iteration 125, training loss: 0.95,
# iteration 130, training loss: 0.90,
# iteration 135, training loss: 0.94,
# iteration 140, training loss: 0.86,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 46.0% 5 way one-shot learning accuracy
# iteration 145, training loss: 0.81,
# iteration 150, training loss: 0.93,
# iteration 155, training loss: 0.81,
# iteration 160, training loss: 0.81,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 52.0% 5 way one-shot learning accuracy
# iteration 165, training loss: 0.82,
# iteration 170, training loss: 0.77,
# iteration 175, training loss: 0.89,
# iteration 180, training loss: 0.79,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 46.0% 5 way one-shot learning accuracy
# iteration 185, training loss: 0.88,
# iteration 190, training loss: 0.86,
# iteration 195, training loss: 0.95,
# iteration 200, training loss: 0.76,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 46.0% 5 way one-shot learning accuracy
# iteration 205, training loss: 0.81,
# iteration 210, training loss: 0.83,
# iteration 215, training loss: 0.76,
# iteration 220, training loss: 0.79,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 52.0% 5 way one-shot learning accuracy
# iteration 225, training loss: 0.74,
# iteration 230, training loss: 0.69,
# iteration 235, training loss: 0.75,
# iteration 240, training loss: 0.73,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 48.0% 5 way one-shot learning accuracy
# iteration 245, training loss: 0.78,
# iteration 250, training loss: 0.82,
# iteration 255, training loss: 0.72,
# iteration 260, training loss: 0.77,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 70.0% 5 way one-shot learning accuracy
# iteration 265, training loss: 0.67,
# iteration 270, training loss: 0.68,
# iteration 275, training loss: 0.69,
# iteration 280, training loss: 0.67,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 60.0% 5 way one-shot learning accuracy
# iteration 285, training loss: 0.68,
# iteration 290, training loss: 0.71,
# iteration 295, training loss: 0.63,
# iteration 300, training loss: 0.71,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 60.0% 5 way one-shot learning accuracy
# iteration 305, training loss: 0.69,
# iteration 310, training loss: 0.73,
# iteration 315, training loss: 0.64,
# iteration 320, training loss: 0.57,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 54.0% 5 way one-shot learning accuracy
# iteration 325, training loss: 0.70,
# iteration 330, training loss: 0.67,
# iteration 335, training loss: 0.63,
# iteration 340, training loss: 0.53,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 46.0% 5 way one-shot learning accuracy
# iteration 345, training loss: 0.66,
# iteration 350, training loss: 0.70,
# iteration 355, training loss: 0.64,
# iteration 360, training loss: 0.69,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 58.0% 5 way one-shot learning accuracy
# iteration 365, training loss: 0.68,
# iteration 370, training loss: 0.66,
# iteration 375, training loss: 0.61,
# iteration 380, training loss: 0.73,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 54.0% 5 way one-shot learning accuracy
# iteration 385, training loss: 0.68,
# iteration 390, training loss: 0.73,
# iteration 395, training loss: 0.59,
# iteration 400, training loss: 0.61,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 58.0% 5 way one-shot learning accuracy
# iteration 405, training loss: 0.63,
# iteration 410, training loss: 0.53,
# iteration 415, training loss: 0.64,
# iteration 420, training loss: 0.69,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 62.0% 5 way one-shot learning accuracy
# iteration 425, training loss: 0.60,
# iteration 430, training loss: 0.61,
# iteration 435, training loss: 0.63,
# iteration 440, training loss: 0.55,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 64.0% 5 way one-shot learning accuracy
# iteration 445, training loss: 0.61,
# iteration 450, training loss: 0.59,
# iteration 455, training loss: 0.50,
# iteration 460, training loss: 0.60,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 58.0% 5 way one-shot learning accuracy
# iteration 465, training loss: 0.66,
# iteration 470, training loss: 0.71,
# iteration 475, training loss: 0.62,
# iteration 480, training loss: 0.60,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 58.0% 5 way one-shot learning accuracy
# iteration 485, training loss: 0.51,
# iteration 490, training loss: 0.60,
# iteration 495, training loss: 0.56,
# iteration 500, training loss: 0.57,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 68.0% 5 way one-shot learning accuracy
# iteration 505, training loss: 0.58,
# iteration 510, training loss: 0.52,
# iteration 515, training loss: 0.55,
# iteration 520, training loss: 0.63,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 52.0% 5 way one-shot learning accuracy
# iteration 525, training loss: 0.50,
# iteration 530, training loss: 0.53,
# iteration 535, training loss: 0.58,
# iteration 540, training loss: 0.60,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 56.0% 5 way one-shot learning accuracy
# iteration 545, training loss: 0.56,
# iteration 550, training loss: 0.54,
# iteration 555, training loss: 0.56,
# iteration 560, training loss: 0.62,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 62.0% 5 way one-shot learning accuracy
# iteration 565, training loss: 0.59,
# iteration 570, training loss: 0.52,
# iteration 575, training loss: 0.44,
# iteration 580, training loss: 0.56,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 68.0% 5 way one-shot learning accuracy
# iteration 585, training loss: 0.56,
# iteration 590, training loss: 0.62,
# iteration 595, training loss: 0.49,
# iteration 600, training loss: 0.56,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 54.0% 5 way one-shot learning accuracy
# iteration 605, training loss: 0.55,
# iteration 610, training loss: 0.55,
# iteration 615, training loss: 0.48,
# iteration 620, training loss: 0.51,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 70.0% 5 way one-shot learning accuracy
# iteration 625, training loss: 0.47,
# iteration 630, training loss: 0.51,
# iteration 635, training loss: 0.60,
# iteration 640, training loss: 0.54,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 54.0% 5 way one-shot learning accuracy
# iteration 645, training loss: 0.55,
# iteration 650, training loss: 0.53,
# iteration 655, training loss: 0.56,
# iteration 660, training loss: 0.47,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 64.0% 5 way one-shot learning accuracy
# iteration 665, training loss: 0.54,
# iteration 670, training loss: 0.51,
# iteration 675, training loss: 0.53,
# iteration 680, training loss: 0.57,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 42.0% 5 way one-shot learning accuracy
# iteration 685, training loss: 0.52,
# iteration 690, training loss: 0.63,
# iteration 695, training loss: 0.60,
# iteration 700, training loss: 0.54,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 66.0% 5 way one-shot learning accuracy
# iteration 705, training loss: 0.56,
# iteration 710, training loss: 0.53,
# iteration 715, training loss: 0.52,
# iteration 720, training loss: 0.50,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 72.0% 5 way one-shot learning accuracy
# iteration 725, training loss: 0.50,
# iteration 730, training loss: 0.50,
# iteration 735, training loss: 0.49,
# iteration 740, training loss: 0.47,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 74.0% 5 way one-shot learning accuracy
# iteration 745, training loss: 0.45,
# iteration 750, training loss: 0.50,
# iteration 755, training loss: 0.50,
# iteration 760, training loss: 0.53,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 76.0% 5 way one-shot learning accuracy
# iteration 765, training loss: 0.54,
# iteration 770, training loss: 0.45,
# iteration 775, training loss: 0.53,
# iteration 780, training loss: 0.51,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 68.0% 5 way one-shot learning accuracy
# iteration 785, training loss: 0.50,
# iteration 790, training loss: 0.44,
# iteration 795, training loss: 0.47,
# iteration 800, training loss: 0.53,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 78.0% 5 way one-shot learning accuracy
# iteration 805, training loss: 0.49,
# iteration 810, training loss: 0.45,
# iteration 815, training loss: 0.48,
# iteration 820, training loss: 0.43,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 66.0% 5 way one-shot learning accuracy
# iteration 825, training loss: 0.42,
# iteration 830, training loss: 0.45,
# iteration 835, training loss: 0.46,
# iteration 840, training loss: 0.59,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 60.0% 5 way one-shot learning accuracy
# iteration 845, training loss: 0.47,
# iteration 850, training loss: 0.53,
# iteration 855, training loss: 0.46,
# iteration 860, training loss: 0.68,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 58.0% 5 way one-shot learning accuracy
# iteration 865, training loss: 0.56,
# iteration 870, training loss: 0.50,
# iteration 875, training loss: 0.45,
# iteration 880, training loss: 0.49,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 60.0% 5 way one-shot learning accuracy
# iteration 885, training loss: 0.38,
# iteration 890, training loss: 0.44,
# iteration 895, training loss: 0.50,
# iteration 900, training loss: 0.42,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 68.0% 5 way one-shot learning accuracy
# iteration 905, training loss: 0.53,
# iteration 910, training loss: 0.49,
# iteration 915, training loss: 0.45,
# iteration 920, training loss: 0.42,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 64.0% 5 way one-shot learning accuracy
# iteration 925, training loss: 0.52,
# iteration 930, training loss: 0.44,
# iteration 935, training loss: 0.50,
# iteration 940, training loss: 0.44,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 84.0% 5 way one-shot learning accuracy
# iteration 945, training loss: 0.49,
# iteration 950, training loss: 0.48,
# iteration 955, training loss: 0.54,
# iteration 960, training loss: 0.43,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 70.0% 5 way one-shot learning accuracy
# iteration 965, training loss: 0.46,
# iteration 970, training loss: 0.54,
# iteration 975, training loss: 0.55,
# iteration 980, training loss: 0.44,
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
# Got an average of 76.0% 5 way one-shot learning accuracy
# iteration 985, training loss: 0.49,
# iteration 990, training loss: 0.39,
# iteration 995, training loss: 0.56,
